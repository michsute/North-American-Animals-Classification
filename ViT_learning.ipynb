# %%
# !pip install transformers datasets torch torchvision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.4 MB/s eta 0:00:00
# ...
#   Using cached regex-2024.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# ...
#   Using cached safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# ...
#   Using cached tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
#   Using cached xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached aiohttp-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# ...
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 20.0 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
import pandas as pd
filtered_metadata_csv = pd.read_csv('/exchange/dspro01/group3/data/filtered_metadata_limited.csv', sep=',')

# %%
filtered_metadata_csv[5999:6002]
# Out:
#        seq_no                                  id  \
# 5999  2717609  FL-34_11_03_2015_FL-34_0000181.jpg
# 6000   477926  CA-12_10_04_2016_CA-12_0015963.JPG
# 6001   341330  CA-02_08_10_2016_CA-02_0017896.JPG
#
#                                              filename study  \
# 5999  part2/sub271/FL-34_11_03_2015_FL-34_0000181.jpg    FL
# 6000  part0/sub047/CA-12_10_04_2016_CA-12_0015963.JPG    CA
# 6001  part0/sub034/CA-02_08_10_2016_CA-02_0017896.JPG    CA
#
#                location  width  height  category_id                      name  \
# 5999       Archbold, FL   2048    1536           26                lynx rufus
# 6000  Lebec, California   2048    1536           50  otospermophilus beecheyi
# 6001  Lebec, California   2048    1536           50  otospermophilus beecheyi
#
#                 genus     family      order     class  \
# 5999             lynx    felidae  carnivora  mammalia
# 6000  otospermophilus  sciuridae   rodentia  mammalia
# ...

# %%
def find_label_with_filename(df, filename):
    return df.loc[df['filename'].str.contains(filename, na=False), 'common_name']

# %%
find_label_with_filename(filtered_metadata_csv, 'CA-08_0000724.jpg')
# Out:
# 16742    empty
# Name: common_name, dtype: object

# %%
filtered_metadata_csv.loc[filtered_metadata_csv['filename'].str.contains('CA-04_10_31_2016_CA-04_0025043.JPG')]
# Out:
#      seq_no                                  id  \
# 999  382821  CA-04_10_31_2016_CA-04_0025043.JPG
#
#                                             filename study           location  \
# 999  part0/sub038/CA-04_10_31_2016_CA-04_0025043.JPG    CA  Lebec, California
#
#      width  height  category_id              name  genus   family      order  \
# 999   2048    1536           67  ursus americanus  ursus  ursidae  carnivora
#
#         class          common_name
# 999  mammalia  american black bear
